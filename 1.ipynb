# %%
for i in range(5):
    print("Hello, World!")

# %%
from ibapi.client import EClient

# %%
import time

def blocking_loop():
    print("进入阻塞循环")
    while True:
        time.sleep(1)
        print("我在阻塞循环里转圈")

blocking_loop()

print("你永远看不到我")
